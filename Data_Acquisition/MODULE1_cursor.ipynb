# %%
import os
import tweepy as tw
import pandas as pd
import json

consumer_key = "nD0Xc1pvKYY3wf4k7DMwyh0Jf"
consumer_secret = "Wm9zfAl9cGY7jKd4MpuG5JznclvzHSYuBjpeX1nCuxyY2NMlwP"
access_token = "1371383340582965248-3J0ohsKuOYY2bmtOGj11DaUQAWlZmH"
access_token_secret = "ZU2mrVjMyckKXjM4CbY9m80395uw6BTfvGEb18Xz9H8yZ"

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

search_words = "any_word_with_no_hashtag" + "#INDvENG" + " -filter:retweets"  
date_since = "2021-03-20"

for tweet in tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000):
    print (tweet.created_at,tweet.text)
    with open('vk_dataset.json', 'a') as f:
        f.write(json.dumps(tweet._json))
        f.write("\n")
# Out:
# 2021-03-20 20:51:48 @KasthuriShankar @ImRo45 Though you are NOBODY and your opinion doesn't even matter still. India in T20Is under Vir… https://t.co/FWZSVyyeq3
# 2021-03-20 20:50:07 Virat Kohli's 80no lead India to a record total as the overpowered England to claim the T20 series 3-2… https://t.co/Sh0jP0KFLp
# 2021-03-20 20:40:14 India vs England T20I Series 2021: Full List of Award Winners, Prize Money, Records, Stats; Kohli-Rohit shine… https://t.co/eYrYlgP6QD
# 2021-03-20 20:40:07 India vs England T20I Series 2021: Full List of Award Winners, Prize Money, Records, Stats; Kohli-Rohit shine… https://t.co/jPZjZDQ2wu
# 2021-03-20 20:27:31 It's a wrap from the T20I leg of the series.
# India win by 36 runs and seal their 8th consecutive T20I series.
# Bhuv… https://t.co/vRxo3WiYeV
# 2021-03-20 20:24:33 💬It's about the two best players getting the maximum number of balls in T20 cricket.💬
#
# Virat Kohli is keen to stay… https://t.co/TaGpiIXZVp
# ...
